# %% [markdown]
# <a href="https://colab.research.google.com/github/Mr-Lee-JC/GitTutor/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
#  Работать с файлом california_housing_train.csv, который находится в папке sample_data. Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population).

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
df[df['population'] < 500]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2        -114.56     33.69                17.0        720.0           174.0
# 7        -114.59     34.83                41.0        812.0           168.0
# 17       -114.65     32.79                21.0         44.0            33.0
# 19       -114.67     33.92                17.0         97.0            24.0
# 21       -114.73     33.43                24.0        796.0           243.0
# ...          ...       ...                 ...          ...             ...
# 16944    -124.14     40.67                23.0        580.0           117.0
# 16951    -124.15     40.81                50.0        340.0            74.0
# 16969    -124.17     40.80                52.0        661.0           316.0
# 16982    -124.18     40.62                35.0        952.0           178.0
# 16994    -124.25     40.28                32.0       1430.0           419.0
#
# ...

# %%
df[(df['population'] < 500) & (df['population'] > 0)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2        -114.56     33.69                17.0        720.0           174.0
# 7        -114.59     34.83                41.0        812.0           168.0
# 17       -114.65     32.79                21.0         44.0            33.0
# 19       -114.67     33.92                17.0         97.0            24.0
# 21       -114.73     33.43                24.0        796.0           243.0
# ...          ...       ...                 ...          ...             ...
# 16944    -124.14     40.67                23.0        580.0           117.0
# 16951    -124.15     40.81                50.0        340.0            74.0
# 16969    -124.17     40.80                52.0        661.0           316.0
# 16982    -124.18     40.62                35.0        952.0           178.0
# 16994    -124.25     40.28                32.0       1430.0           419.0
#
# ...

# %%
df[(df['population'] < 500) & (df['population'] > 0)]['median_house_value']
# Out:
# 2         85700.0
# 7         48500.0
# 17        25000.0
# 19        27500.0
# 21        59200.0
#            ...
# 16944    130600.0
# 16951     67500.0
# 16969     60000.0
# 16982    107000.0
# 16994     76100.0
# Name: median_house_value, Length: 1601, dtype: float64

# %% [markdown]
# Узнать какая максимальная households в зоне минимального значения population.

# %%
df['population'].min()
# Out:
# 3.0

# %%
df[df['population'] == df['population'].min()]['households'].max()
# Out:
# 4.0
